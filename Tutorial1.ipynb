# %%
tu = (23, 'abc', 4.56, (2,3), 'def')

# %%
print(tu)
# Out:
# (23, 'abc', 4.56, (2, 3), 'def')

# %%
li = ["abc", 34, 4.34, 23]

# %%
st = "Hello World"
st = 'Hello World'
st = """This is a multi-line
string that uses triple quotes."""

# %%
print(li)
# Out:
# ['abc', 34, 4.34, 23]

# %%
tu[1]
# Out:
# 'abc'

# %%
st[1]
# Out:
# 'h'

# %%
li[1:3]
# Out:
# [34, 4.34]

# %%
li[:3]
# Out:
# ['abc', 34, 4.34]

# %%
li[:3:2]
# Out:
# ['abc', 4.34]

# %%
t = (23, 'abc', 4.56, (2,3), 'def')

# %%
t[1]
# Out:
# 'abc'

# %%
t[-3]
# Out:
# 4.56

# %%
4 in t
# Out:
# False

# %%
t[1:4]
# Out:
# ('abc', 4.56, (2, 3))

# %%
t[1:-1]
# Out:
# ('abc', 4.56, (2, 3))

# %%
t[1:-1:2]
# Out:
# ('abc', (2, 3))

# %%
t[:2]

# %%
t[2:]

# %%
t[:]
# Out:
# (23, 'abc', 4.56, (2, 3), 'def')

# %%
list1 = [1, 2, 3]

# %%
list2 = list1

# %%
list2[1] = 99

# %%
list2
# Out:
# [1, 99, 3]

# %%
list1
# Out:
# [1, 99, 3]

# %%
t = [1, 2, 4, 5]

# %%
3 in t

# %%
4 in t

# %%
a = 'abcde'

# %%
(1, 2, 3) + (4, 5, 6)

# %%
[1, 2, 3] + [4, 5, 6]

# %%
"Hello" + " " + "World"
